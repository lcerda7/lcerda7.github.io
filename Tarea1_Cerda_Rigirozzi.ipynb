# %% [markdown]
# <a href="https://colab.research.google.com/github/lcerda7/lcerda7.github.io/blob/master/Tarea1_Cerda_Rigirozzi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Trabajo Practico 1. Luis Cerda y Gonzalo Rigirozzi*
#
# ---

# %%
import pandas as pd

# %%
#1
url = 'https://raw.githubusercontent.com/gp-gv-nc/Tarea1/main/tarea.csv'
df1=pd.read_csv(url)
df1.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
#2 leer el archivo csv “tarea” y mostrar las primeras 3 filas (,nrows=3).

df1.head(3)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31

# %% [markdown]
# # New Section

# %%
#3 Imprime el contenido de una columna como serie (tan sólo imprimí la columna entre corchetes!)
df1[['cut']]
# Out:
#              cut
# 0          Ideal
# 1        Premium
# 2           Good
# 3        Premium
# 4           Good
# ...          ...
# 53935      Ideal
# 53936       Good
# 53937  Very Good
# 53938    Premium
# 53939      Ideal
#
# [53940 rows x 1 columns]

# %%
#4 crear una nueva serie 'calidad-color' (utilizá corchetes para definir el nombre de la serie)
df1['calidad-color']=df1['clarity']+df1['color']
df1
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       calidad-color
# 0              SI2E
# 1              SI1E
# 2              VS1E
# 3              VS2I
# 4              SI2J
# ...             ...
# 53935          SI1D
# 53936          SI1D
# 53937          SI1D
# 53938          SI2H
# 53939          SI2D
#
# [53940 rows x 11 columns]

# %%
#5 encontrar el número de filas y columnas (.shape)) y el tipo de datos de cada columna (.dtypes).
print(df1.shape)
print(df1.dtypes)
# Out:
# (53940, 11)
# carat            float64
# cut               object
# color             object
# clarity           object
# depth            float64
# table            float64
# price              int64
# x                float64
# y                float64
# z                float64
# calidad-color     object
# dtype: object

# %%
#6 resumir sólo las columnas 'objeto' (.describe(include=['object'])).
df1.describe(include=['object'])
# Out:
#           cut  color clarity calidad-color
# count   53940  53940   53940         53940
# unique      5      7       8            56
# top     Ideal      G     SI1          VS2E
# freq    21551  11292   13065          2470

# %%
#7 renombrar dos de las columnas (.rename(columns={…). 
#Imprimir antes y después incluyendo una línea que describa cada una (ej print("Original"))
print('Original')
df1
# Out:
# Original
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       calidad-color
# 0              SI2E
# 1              SI1E
# 2              VS1E
# 3              VS2I
# 4              SI2J
# ...             ...
# 53935          SI1D
# 53936          SI1D
# 53937          SI1D
# 53938          SI2H
# 53939          SI2D
#
# [53940 rows x 11 columns]

# %%
#7
print('Rename')
df1=df1.rename(columns={'cut':'Cut level', 'price':'Precio'})
df1
# Out:
# Rename
#        carat  Cut level color clarity  depth  table  Precio     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0     326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0     326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0     327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0     334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0     335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...     ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0    2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0    2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0    2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0    2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0    2757  5.83  5.87  3.64
#
#       calidad-color
# 0              SI2E
# 1              SI1E
# 2              VS1E
# 3              VS2I
# 4              SI2J
# ...             ...
# 53935          SI1D
# 53936          SI1D
# 53937          SI1D
# 53938          SI2H
# 53939          SI2D
#
# [53940 rows x 11 columns]

# %%
#8 eliminar la segunda y tercer columna (.drop())
df1.drop(columns=['Cut level','color'])
# Out:
#        carat clarity  depth  table  Precio     x     y     z calidad-color
# 0       0.23     SI2   61.5   55.0     326  3.95  3.98  2.43          SI2E
# 1       0.21     SI1   59.8   61.0     326  3.89  3.84  2.31          SI1E
# 2       0.23     VS1   56.9   65.0     327  4.05  4.07  2.31          VS1E
# 3       0.29     VS2   62.4   58.0     334  4.20  4.23  2.63          VS2I
# 4       0.31     SI2   63.3   58.0     335  4.34  4.35  2.75          SI2J
# ...      ...     ...    ...    ...     ...   ...   ...   ...           ...
# 53935   0.72     SI1   60.8   57.0    2757  5.75  5.76  3.50          SI1D
# 53936   0.72     SI1   63.1   55.0    2757  5.69  5.75  3.61          SI1D
# 53937   0.70     SI1   62.8   60.0    2757  5.66  5.68  3.56          SI1D
# 53938   0.86     SI2   61.0   58.0    2757  6.15  6.12  3.74          SI2H
# 53939   0.75     SI2   62.2   55.0    2757  5.83  5.87  3.64          SI2D
#
# [53940 rows x 9 columns]

# %%
#9 eliminar múltiples filas a la vez (usar axis=0 que se refiere a las filas).
df1.drop([1, 2, 3, 4],axis=0)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94   NaN  2.48
# 6       0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7       0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8       0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53936 rows x 10 columns]

# %%
#10 ordenar la columna `cut’ en orden ascendente (tarea.cut.sort_values). 
#¿Qué tipo de objeto es `cut’ usándolo así? 

df1['cut'].sort_values()
# Out:
# 3850          Fair
# 51464         Fair
# 51466         Fair
# 10237         Fair
# 10760         Fair
#            ...
# 7402     Very Good
# 43101    Very Good
# 16893    Very Good
# 16898    Very Good
# 21164    Very Good
# Name: cut, Length: 53940, dtype: object

# %%
#Es String 
type('cut')
# Out:
# str

# %%
#11 ordenar toda la base por 'carat' en orden descendente.
df1.sort_values('carat', ascending=False)
# Out:
#        carat      cut color clarity  depth  table  price      x      y     z
# 27415   5.01     Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
# 27630   4.50     Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 27130   4.13     Fair     H      I1   64.8   61.0  17329  10.00   9.85  6.43
# 25999   4.01  Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# 25998   4.01  Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
# ...      ...      ...   ...     ...    ...    ...    ...    ...    ...   ...
# 31592   0.20  Premium     E     VS2   59.0   60.0    367   3.81   3.78  2.24
# 31591   0.20  Premium     E     VS2   59.8   62.0    367   3.79   3.77  2.26
# 31601   0.20  Premium     D     VS2   61.7   60.0    367   3.77   3.72  2.31
# 14      0.20  Premium     E     SI2   60.2   62.0    345   3.79   3.75  2.27
# 31596   0.20  Premium     F     VS2   62.6   59.0    367   3.73   3.71  2.33
#
# [53940 rows x 10 columns]

# %%
#12 filtrar aquellas filas que x>5, y>5 y z>5.
df1[(df1['x']>5) & (df1['y']>5) & (df1['z']>5)]
# Out:
#        carat        cut color clarity  depth  table  price     x      y  \
# 11778   1.83       Fair     J      I1   70.0   58.0   5083  7.34   7.28
# 13002   2.14       Fair     J      I1   69.4   57.0   5405  7.74   7.70
# 13118   2.15       Fair     J      I1   65.5   57.0   5430  8.01   7.95
# 13562   1.96       Fair     F      I1   66.6   60.0   5554  7.59   7.56
# 13757   2.22       Fair     J      I1   66.7   56.0   5607  8.04   8.02
# ...      ...        ...   ...     ...    ...    ...    ...   ...    ...
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90   7.97
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823  8.50   8.47
# 48410   0.51  Very Good     E     VS1   61.8   54.7   1970  5.12   5.15
# 49189   0.51      Ideal     E     VS1   61.8   55.0   2075  5.15  31.80
# 49905   0.50  Very Good     G    VVS1   63.7   58.0   2180  5.01   5.04
#
#            z calidad-color
# 11778   5.12           I1J
# 13002   5.36           I1J
# 13118   5.23           I1J
# 13562   5.04           I1F
# 13757   5.36           I1J
# ...      ...           ...
# 27748   5.04          SI1G
# 27749   5.16          VS2I
# 48410  31.80          VS1E
# 49189   5.12          VS1E
# 49905   5.06         VVS1G
#
# [1457 rows x 11 columns]

# %%
#13 filtrar las filas para que sólo muestren `carat’ mayor a 0,4 (usar for x in tarea.carat:…
df1[(df1['carat']>0.4)]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 64      0.42    Premium     I     SI2   61.5   59.0    552  4.78  4.84  2.96
# 90      0.70      Ideal     E     SI1   62.5   57.0   2757  5.70  5.72  3.57
# 91      0.86       Fair     E     SI2   55.1   69.0   2757  6.45  6.33  3.52
# 92      0.70      Ideal     G     VS2   61.6   56.0   2757  5.70  5.67  3.50
# 93      0.71  Very Good     E     VS2   62.4   57.0   2759  5.68  5.73  3.56
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [39549 rows x 10 columns]

# %%
#14 filtrar filas que son Premium o Ideal (tarea.cut.sin() o usar |).
df1[df1.cut.str.contains('Premium|Ideal')]
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 0       0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 11      0.23    Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 12      0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53931   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53934   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53935   0.72    Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53938   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75    Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [35342 rows x 10 columns]

# %%
#15calcular summary statistics de  `carat’ (.describe). 
df1['carat'].describe()
# Out:
# count    53940.000000
# mean         0.797940
# std          0.474011
# min          0.200000
# 25%          0.400000
# 50%          0.700000
# 75%          1.040000
# max          5.010000
# Name: carat, dtype: float64

# %%
#16calcular la media de cada columna numérica (.mean())
print(df1.mean())
# Out:
# carat       0.797940
# depth      61.749405
# table      57.457184
# price    3932.799722
# x           5.731157
# y           5.734559
# z           3.538734
# dtype: float64
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %%
#17calcular la media del precio de cada tipo de `cut’ (tarea.groupby().price.mean())
df1.groupby(['cut']).mean()
# Out:
#               carat      depth      table        price         x         y  \
# cut
# Fair       1.046137  64.041677  59.053789  4358.757764  6.246894  6.182652
# Good       0.849185  62.365879  58.694639  3928.864452  5.838785  5.850744
# Ideal      0.702837  61.709401  55.951668  3457.541970  5.507451  5.520080
# Premium    0.891955  61.264673  58.746095  4584.257704  5.973887  5.944879
# Very Good  0.806381  61.818275  57.956150  3981.759891  5.740696  5.770175
#
#                   z
# cut
# Fair       3.982770
# Good       3.639507
# Ideal      3.401448
# Premium    3.647124
# Very Good  3.559801

# %%
#18 calcular la cantidad, el mínimo y el máximo precio para cada `cut’ ((tarea.groupby().price.agg([]))).

df1.groupby(['cut']).price.agg(['min', 'max','sum'])
# Out:
#            min    max       sum
# cut
# Fair       337  18574   7017600
# Good       327  18788  19275009
# Ideal      326  18806  74513487
# Premium    326  18823  63221498
# Very Good  336  18818  48107623

# %%
#19 mostrar los valores que puede tomar `cut’ (.unique())
df1['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
#20 contar cuántas veces aparece cada valor de `cut’ ((tarea.cut.value_counts()))
df1['cut'].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
#21 mostrar los porcentajes de cada valor de `cut’.
df1.cut.value_counts() / len(df1.cut) * 100
# Out:
# Ideal        39.953652
# Premium      25.567297
# Very Good    22.398962
# Good          9.095291
# Fair          2.984798
# Name: cut, dtype: float64

# %%
#22 calcular una tabla de doble entrada con `cut’ y `color’ (pd.crosstab)
pd.crosstab(df1['cut'], df1['color'])
# Out:
# color         D     E     F     G     H     I    J
# cut
# Fair        163   224   312   314   303   175  119
# Good        662   933   909   871   702   522  307
# Ideal      2834  3903  3826  4884  3115  2093  896
# Premium    1603  2337  2331  2924  2360  1428  808
# Very Good  1513  2400  2164  2299  1824  1204  678

# %%
#23 crear un histograma de ‘cut’ (.plot(kind=’hist’)).
#df1.plot.hist('cut')
df1.groupby('cut').plot(kind='hist')
# Out:
# cut
# Fair         AxesSubplot(0.125,0.125;0.775x0.755)
# Good         AxesSubplot(0.125,0.125;0.775x0.755)
# Ideal        AxesSubplot(0.125,0.125;0.775x0.755)
# Premium      AxesSubplot(0.125,0.125;0.775x0.755)
# Very Good    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
#24 crear un gráfico de barras de 'cut'
df1_cut = df1.pivot_table(index = ['cut'], aggfunc ='size')
df1_cut.plot(kind='bar')

# %%
#25 contar el número de missing valies en cada columna (.isnull().sum()).
df1.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          1
# z          0
# dtype: int64

# %%
#26 comprobar el número de filas y columnas y eliminarlas si falta algún valor en una fila (.dropna(how='any')).
df1.dropna(how='any')
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53939 rows x 10 columns]

# %%
#27 eliminar una fila si faltan todos los valores ((.dropna(how='all'))
df1.dropna(how='all')
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
#28 mostrar las filas 0, 2, 5 y todas las columnas (.loc[]).
df1.loc[[0,2,5]]
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94   NaN  2.48

# %%
#29 mostrar las filas 0 a 2 (inclusive) y las columnas 'color' y 'precio' 
df1.loc[0:2, ['color','price']]
# Out:
#   color  price
# 0     E    326
# 1     E    326
# 2     E    327

# %%
#30 mostrar las filas en las que la 'cut' es 'Premium' más la columna 'color'
df1[(df1['cut'] == 'Premium') & (df1['color'])]
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 12      0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# 14      0.20  Premium     E     SI2   60.2   62.0    345  3.79  3.75  2.27
# 15      0.32  Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53928   0.79  Premium     E     SI2   61.4   58.0   2756  6.03  5.96  3.68
# 53930   0.71  Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53931   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53934   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53938   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
#
# [13791 rows x 10 columns]

# %%
#31 obtener 5 filas de muestra al azar (.sample()). 
df1.sample(5)
# Out:
#        carat    cut color clarity  depth  table  price     x     y     z
# 39035   0.37  Ideal     G      IF   62.1   55.0   1056  4.60  4.64  2.87
# 24233   1.57  Ideal     F     SI1   61.1   55.0  12432  7.55  7.53  4.61
# 47282   0.30   Good     I     SI1   63.3   59.0    394  4.22  4.25  2.68
# 9435    1.00   Good     H     SI2   57.9   62.0   4592  6.53  6.49  3.77
# 15934   1.22  Ideal     D     SI2   61.8   58.0   6372  6.84  6.92  4.25

# %%
#32 obtener una muestra del 75% de las filas sin reemplazarlas (.sample(frac=0.75, random_state=XX))
df1.sample(frac=0.75)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 25978   1.54    Premium     E     VS2   62.7   58.0  15178  7.33  7.37  4.61
# 27916   0.32  Very Good     D     VS2   62.9   59.0    657  4.36  4.39  2.75
# 23153   1.61    Premium     H     SI1   60.8   56.0  11169  7.61  7.58  4.62
# 45376   0.70  Very Good     J     SI1   61.9   58.0   1666  5.64  5.67  3.50
# 28927   0.30       Good     G    VVS2   63.6   57.0    684  4.26  4.30  2.72
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 22018   1.50      Ideal     H     VS1   61.3   55.0  10080  7.37  7.34  4.51
# 50391   0.72      Ideal     H     SI2   60.8   56.0   2252  5.79  5.83  3.53
# 30385   0.33      Ideal     G    VVS2   61.7   55.0    730  4.46  4.49  2.76
# 46088   0.53      Ideal     E     VS2   61.3   55.0   1739  5.22  5.25  3.21
# 52154   0.70  Very Good     G     VS1   63.2   58.0   2473  5.61  5.65  3.56
#
# [40455 rows x 10 columns]

# %%
#33 contar las filas duplicadas.
dups = df1.pivot_table(index = ['cut'], aggfunc ='size')
print(dups)
# Out:
# cut
# Fair          1610
# Good          4906
# Ideal        21551
# Premium      13791
# Very Good    12082
# dtype: int64
